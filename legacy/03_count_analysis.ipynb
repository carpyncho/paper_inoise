# %%
import pickle
from collections import Counter

import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
with open("./data/count.pkl") as fp:
    count = pickle.load(fp)
with open("./data/count_high.pkl") as fp:
    counth = pickle.load(fp)
with open("./data/count_low.pkl") as fp:
    countl = pickle.load(fp)

# %%
total = Counter()
map(total.update, count);
# total.pop(0)

# del count, counth, countl

# %%
from libs import cnt_stats

# %%
cnt_stats.mean(total), cnt_stats.mean(high), cnt_stats.mean(low)
# Out:
# (49.080125465093019, 43.74848248248248, 57.57266666666667)

# %%
# sorted(total.items())

# %%
total_v = np.sum(total.values())
values = np.array(sorted(total.keys()))
sort = np.cumsum(np.array([v for k, v in sorted(total.items())]))

# %%
np.sum(total.values())
# Out:
# 12497500

# %%
np.argmax(sort >= (total_v / 2.))
# Out:
# 51

# %%
no_zero = {k: v for k, v in total.items() }
plt.plot(no_zero.values())
plt.axvline(
    cnt_stats.mean(total), color="g", ls="-", 
    label="Mean: {:.2f}".format(cnt_stats.mean(total)))
plt.axvline(
    50.5, color="r", ls="-", 
    label="Median: {:.2f}".format(50.5))
plt.title("Vicinity count for 5000 sources - Tile b396")
plt.xlabel("Vicinity count")
plt.ylabel("Pairs")
plt.legend()
plt.savefig("figs/vicinitycount_b396.pdf", bbox_inches='tight')

# %%
plt.plot(high.values(), color="y")

# %%
plt.plot(low.values(), color="y")
